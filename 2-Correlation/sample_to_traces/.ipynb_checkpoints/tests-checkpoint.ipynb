# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.fromfile("traces/1344x806@60.trace", count=1_000_000, dtype=np.float32)

data_plt = data
#[data[i] for i in range(0,10_000_000,20)]
print(data)

plt.plot(data_plt)
# Out:
# [ 0.          0.          0.         ... -0.03262428  0.04544205
#   0.03845331]

# %%
np.min(data_plt)
# Out:
# -1.0000303

# %%
sample_size = 5*10**5
print(sample_size)
plt.plot(data[0:sample_size])
# Out:
# 500000

# %%
def mean(X):
    return np.sum(X, axis=0)/len(X)

def std_dev(X, X_bar):
    return np.sqrt(np.sum((X-X_bar)**2, axis=0))

def cov(X, X_bar, Y, Y_bar):
    return np.sum((X-X_bar)*(Y-Y_bar), axis=0)

def pearson(X,Y):
    X_mean = mean(X)
    Y_mean = mean(Y)    
    return cov(X, X_mean, Y, Y_mean)/(std_dev(X, X_mean)*std_dev(Y, Y_mean))

# %%
samp1 = data[0:sample_size]
samp2 = data[sample_size:sample_size*2]

# %%
r = pearson(samp1, samp2)
print(r)
# Out:
# 0.99873
